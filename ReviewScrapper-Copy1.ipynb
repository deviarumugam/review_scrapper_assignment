# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
URL = "https://www.walmart.com/reviews/product/39132424"

# %%
req_data = requests.get(URL)
review_soup = BeautifulSoup(req_data.content, 'html.parser')

# %%
print(dir(req_data))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
review_soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# ...

# %%
all_reviews = review_soup.find_all('div', class_='collapsable-content-container')
positive_reviews = review_soup.find_all('div', class_='Grid-col w50-mr')
negative_reviews = review_soup.find_all('div', class_='Grid-col w50-ml')

# %%
all_reviews
# Out:
# [<div class="collapsable-content-container"><div>Are you kidding me?   i hesitated to make this purchase due to some complaints regarding the closings of the bags etc.  I figuared for the price I'd use them for overnight storage should the closings be weak.  Glad i tried them for myself.
#  These little workhorses have been an asset for so many small uses, due to their
#  size.  Great as sandwich bags and more.  They'll keep uneaten puppy food over
#  night when my fussy friend leave too much to discard.  I don't like placeing his
#  leftovers in my washable containers.  Then there are uses in the garage, the
# ...

# %%
positive_reviews
# Out:
# [<div class="Grid-col w50-mr"><div class="font-bold highlight-title">Most helpful positive review</div><div class="highlight-title-container"><div class="highlight-review-stars"><div class="arranger stars stars-small arranger--items-center"><span class="stars-container"><span aria-hidden="true" class="elc-icon star star-small star-rated elc-icon-star-rating" data-automation-id="stars-star-0"></span><span aria-hidden="true" class="elc-icon star star-small star-rated elc-icon-star-rating" data-automation-id="stars-star-1"></span><span aria-hidden="true" class="elc-icon star star-small star-rated elc-icon-star-rating" data-automation-id="stars-star-2"></span><span aria-hidden="true" class="elc-icon star star-small star-rated elc-icon-star-rating" data-automation-id="stars-star-3"></span><span aria-hidden="true" class="elc-icon star star-small star-rated elc-icon-star-rating" data-automation-id="stars-star-4"></span></span><span aria-hidden="false" class="visuallyhidden hiddenStarLabel" 
# ...

# %%
negative_reviews
# Out:
# [<div class="Grid-col w50-ml"><div class="font-bold highlight-title">Most helpful negative review</div><div class="highlight-title-container"><div class="highlight-review-stars"><div class="arranger stars stars-small arranger--items-center"><span class="stars-container"><span aria-hidden="true" class="elc-icon star star-small star-rated elc-icon-star-rating" data-automation-id="stars-star-0"></span><span aria-hidden="true" class="elc-icon star star-small star-rated elc-icon-star-rating" data-automation-id="stars-star-1"></span><span aria-hidden="true" class="elc-icon star star-small star-empty elc-icon-star-rating" data-automation-id="stars-star-2"></span><span aria-hidden="true" class="elc-icon star star-small star-empty elc-icon-star-rating" data-automation-id="stars-star-3"></span><span aria-hidden="true" class="elc-icon star star-small star-empty elc-icon-star-rating" data-automation-id="stars-star-4"></span></span><span aria-hidden="false" class="visuallyhidden hiddenStarLabel" 
# ...

# %%
full_review_list=[]
for review in all_reviews:
    full_review_list1 = review.find_all('div')#, class_='collapsable-content-container')
    full_review_list1=[e.get_text() for e in full_review_list1]
    full_review_list.append(full_review_list1)

# %%
for i in full_review_list:
    print(i)
# Out:
# ["Are you kidding me?   i hesitated to make this purchase due to some complaints regarding the closings of the bags etc.  I figuared for the price I'd use them for overnight storage should the closings be weak.  Glad i tried them for myself.\nThese little workhorses have been an asset for so many small uses, due to their \nsize.  Great as sandwich bags and more.  They'll keep uneaten puppy food over \nnight when my fussy friend leave too much to discard.  I don't like placeing his\nleftovers in my washable containers.  Then there are uses in the garage, the \nbathroom shelves, the office room and more,  Your dollars are not wasted here.", '', '', '', '', '']
# ["I have been buying this product for 5+years and have been very pleased with the quality.  The box just received is obviously from a new vendor. It is not as sturdy and the double seal is flimsy and doesn't close securely. I will not purchase this product again.", '', '', '', '', '']
# ...

# %%
all_reviews_star = review_soup.find_all('div', class_='review-star-rating')
star_rating=[]
for review in all_reviews_star:
    star_rating1 = review.find_all('div')
    star_rating1=[e.get_text() for e in star_rating1]
    star_rating.append(star_rating1)
for i in star_rating:
    print(i)
# Out:
# ['Average rating:5out of5stars, based on408reviews408ratings']
# ['Average rating:5out of5stars, based on408reviews408ratings']
# ['Average rating:5out of5stars, based on408reviews408ratings']
# ['Average rating:5out of5stars, based on408reviews408ratings']
# ['Average rating:5out of5stars, based on408reviews408ratings']
# ['Average rating:4out of5stars, based on408reviews408ratings']
# ['Average rating:3out of5stars, based on408reviews408ratings']
# ['Average rating:2out of5stars, based on408reviews408ratings']
# ['Average rating:1out of5stars, based on408reviews408ratings']
# ['Average rating:1out of5stars, based on408reviews408ratings']
# ['Average rating:5out of5stars, based on408reviews408ratings']
# ['Average rating:3out of5stars, based on408reviews408ratings']
# ['Average rating:5out of5stars, based on408reviews408ratings']
# ['Average rating:5out of5stars, based on408reviews408ratings']
# ['Average rating:5out of5stars, based on408reviews408ratings']
# ...

# %%
all_reviews_star
# Out:
# [<div class="review-star-rating"><div class="arranger stars stars-small arranger--items-center"><span class="stars-container"><span aria-hidden="true" class="elc-icon star star-small star-rated elc-icon-star-rating" data-automation-id="stars-star-0"></span><span aria-hidden="true" class="elc-icon star star-small star-rated elc-icon-star-rating" data-automation-id="stars-star-1"></span><span aria-hidden="true" class="elc-icon star star-small star-rated elc-icon-star-rating" data-automation-id="stars-star-2"></span><span aria-hidden="true" class="elc-icon star star-small star-rated elc-icon-star-rating" data-automation-id="stars-star-3"></span><span aria-hidden="true" class="elc-icon star star-small star-rated elc-icon-star-rating" data-automation-id="stars-star-4"></span></span><span aria-hidden="false" class="visuallyhidden hiddenStarLabel" data-automation-id="stars-avg-rating">Average rating:<span class="seo-avg-rating">5</span>out of<span class="seo-best-rating">5</span>stars, base
# ...

# %%
searchString = request.form['content'].replace(" ", "")
            flipkart_url = "https://www.flipkart.com/search?q=" + searchString
            uClient = uReq(flipkart_url)
            flipkartPage = uClient.read()
            uClient.close()
            flipkart_html = bs(flipkartPage, "html.parser")
            bigboxes = flipkart_html.findAll("div", {"class": "bhgxx2 col-12-12"})
            del bigboxes[0:3]
            box = bigboxes[0]
            productLink = "https://www.flipkart.com" + box.div.div.div.a['href']
            prodRes = requests.get(productLink)
            prodRes.encoding = 'utf-8'
            prod_html = bs(prodRes.text, "html.parser")
            print(prod_html)
            commentboxes = prod_html.find_all('div', {'class': "_3nrCtb"})
            filename = searchString + ".csv"
            fw = open(filename, "w")
            headers = "Product, Customer Name, Rating, Heading, Comment \n"
            fw.write(headers)
            reviews = []
            for commentbox in commentboxes:
                try:
                    # name.encode(encoding='utf-8')
                    name = commentbox.div.div.find_all('p', {'class': '_3LYOAd _3sxSiS'})[0].text
                except:
                    name = 'No Name'
                try:
                    # rating.encode(encoding='utf-8')
                    rating = commentbox.div.div.div.div.text
                except:
                    rating = 'No Rating'
                try:
                    # commentHead.encode(encoding='utf-8')
                    commentHead = commentbox.div.div.div.p.text
                except:
                    commentHead = 'No Comment Heading'
                try:
                    comtag = commentbox.div.div.find_all('div', {'class': ''})
                    # custComment.encode(encoding='utf-8')
                    custComment = comtag[0].div.text
                except Exception as e:
                    print("Exception while creating dictionary: ", e)
                mydict = {"Product": searchString, "Name": name, "Rating": rating, "CommentHead": commentHead,
                          "Comment": custComment}
                reviews.append(mydict)
            return render_template('results.html', reviews=reviews[0:(len(reviews) - 1)])
        except Exception as e:
            print('The Exception message is: ', e)
            return 'something is wrong'
    # return render_template('results.html')

# %%
#searchString = request.form['content'].replace(" ", "")
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import requests
searchString='ziploc'
walmart_url = "https://www.walmart.com/search/?query=" + searchString
req_data = requests.get(walmart_url)
review_soup = BeautifulSoup(req_data.content, 'html.parser')
review_soup
#uClient = uReq(walmart_url)
#uClient
#walmartPage = uClient.read()
#uClient.close()
#walmart_html = bs(walmartPage, "html.parser")
#walmart_html
#bigboxes = walmart_html.findAll("div", {"class": "bhgxx2 col-12-12"})
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <style class="bogel-font">
# ...

# %%
all_reviews = review_soup.find_all('div', class_='collapsable-content-container')
positive_reviews = review_soup.find_all('div', class_='Grid-col w50-mr')
negative_reviews = review_soup.find_all('div', class_='Grid-col w50-ml')

# %%
all_reviews
# Out:
# [<div class="collapsable-content-container"><ul class="sub-dept-list" id="hidden-sub-dept-list0" style="display:none"><li><a class="" href="?query=ziploc&amp;cat_id=1115193_2606160&amp;grid=true">Household Clean Living Shop</a></li><li><a class="" href="?query=ziploc&amp;cat_id=1115193_6173477&amp;grid=true">Household Essentials by Room</a></li><li><a class="" href="?query=ziploc&amp;cat_id=1115193_1071968&amp;grid=true">Kitchen</a></li></ul><div style="position:absolute;left:0;top:0;right:0;bottom:0;overflow:hidden;z-index:-1;visibility:hidden;pointer-events:none"><div style="position:absolute;left:0;top:0;right:0;bottom:0;overflow:hidden;z-index:-1;visibility:hidden;pointer-events:none"><div style="position:absolute;left:0;top:0;transition:0s;width:100000px;height:100000px"></div></div><div style="position:absolute;left:0;top:0;right:0;bottom:0;overflow:hidden;z-index:-1;visibility:hidden;pointer-events:none"><div style="position:absolute;left:0;top:0;transition:0s;width:200%;heigh
# ...

# %%
all_reviews = review_soup.find_all('div', class_='page-content-wrapper')
all_reviews
# Out:
# [<div class="page-content-wrapper"><div class="product-review ResponsiveContainer"><div class="back-panel hide-content-m"><a aria-label="Back to Item page" class="back-panel-link" href="/ip/39132424"><span aria-hidden="true" class="elc-icon elc-icon-angle-left elc-icon-24"></span><span class="back-btn">Back</span></a></div><div class="hide-content-max-m breadcrumb-decoration"><nav aria-label="breadcrumb" data-automation-id="breadcrumb" path="[object Object],[object Object],[object Object],[object Object]" role="navigation"><ol class="breadcrumb-list" itemscope="" itemtype="//schema.org/BreadcrumbList"><li class="breadcrumb" data-automation-id="breadcrumb-item-0" itemprop="itemListElement" itemscope="" itemtype="//schema.org/ListItem"><a aria-label="Household Essentials, Breadcrumb element 1 of 4" class="" href="/cp/1115193" itemprop="item" itemscope="" itemtype="//schema.org/Thing">Household Essentials</a><meta content="1" itemprop="position"/></li><li class="breadcrumb" data-automat
# ...

# %%
query="ziploc bags"
url="https://www.walmart.com/search/?query="+query
req_data = requests.get(url)
review_soup = BeautifulSoup(req_data.content, 'html.parser')
review_soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <style class="bogel-font">
# ...

# %%
all_reviews = review_soup.find_all('a','review-wrapper','href')
all_reviews
for i in all_reviews:
    print(i.get_attribute('href'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-79947c5c9227> in <module>
#       2 all_reviews
#       3 for i in all_reviews:
# ----> 4     print(i.get_attribute(href))
#
# NameError: name 'href' is not defined

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup 
import requests
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.support import expected_conditions as EC
browser = webdriver.Chrome("C:/Users/Sreenivasan/PycharmProjects/imagescrapper1/chromedriver.exe")
product_id="ziploc"
url = "https://www.walmart.com/search/?query="+product_id
review=browser.get(url)
content = browser.find_element_by_class_name('orientation-square')
content.click()
c_url=browser.current_url
#product_id="365635198"
#url = "https://www.walmart.com/reviews/product/"+product_id
#review =browser.get(url)
c_urlreview=requests.get(c_url)
review_soup = BeautifulSoup(c_urlreview.content, 'html.parser')
all_reviews = review_soup.find_all('div', class_='collapsable-content-container')
#print(all_reviews) 
#for i in all_reviews:
    #print(i.get_text('p'))
for j in all_reviews:
        #print(j.get_text())
        k=j.get_text()
        print(k)
#
#commentboxes=review_soup.find_all('div', {'class': 'collapsable-content-container'})
#reviews = []
#for commentbox in commentboxes:
#    comtag = commentbox.div.div.find_all('div', {'data-automation-id': 'top-positive-review-text'})
    # custComment.encode(encoding='utf-8')
#    custComment = comtag[0].get_text()
#    mydict = {"Comment": custComment}
#    reviews.append(mydict)
#    print(reviews)
# Out:
# Are you kidding me?   i hesitated to make this purchase due to some complaints regarding the closings of the bags etc.  I figuared for the price I'd use them for overnight storage should the closings be weak.  Glad i tried them for myself.
# These little workhorses have been an asset for so many small uses, due to their
# size.  Great as sandwich bags and more.  They'll keep uneaten puppy food over
# night when my fussy friend leave too much to discard.  I don't like placeing his
# leftovers in my washable containers.  Then there are uses in the garage, the
# bathroom shelves, the office room and more,  Your dollars are not wasted here.
# I have been buying this product for 5+years and have been very pleased with the quality.  The box just received is obviously from a new vendor. It is not as sturdy and the double seal is flimsy and doesn't close securely. I will not purchase this product again.
# ...

# %%
commentboxes=review_soup.find_all('div', class_='collapsable-content-container')
reviews = []
for commentbox in commentboxes:
    comtag = commentbox.div.div.find_all('div', {'class': 'collapsable-content-container'})
    # custComment.encode(encoding='utf-8')
    custComment = comtag[0].div.text
    mydict = {"Comment": custComment}
    reviews.append(mydict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-c9bdcb58a112> in <module>
#       2 reviews = []
#       3 for commentbox in commentboxes:
# ----> 4     comtag = commentbox.div.div.find_all('div', {'class': 'collapsable-content-container'})
#       5     # custComment.encode(encoding='utf-8')
#       6     custComment = comtag[0].div.text
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
search_str="ziploc"
browser = webdriver.Chrome("C:/Users/Sreenivasan/PycharmProjects/imagescrapper1/chromedriver.exe")
url1="https://www.walmart.com/search/?query="+search_str
get1=browser.get(url1)
review_soup1 = BeautifulSoup(review.content, 'html.parser')
all_reviews1=review_soup1.find_all('div',class_='wpa-brand-products')#class_='search-result-productimage gridview display-block')
all_reviews1
#for i in all_results1:
#    print(i.get_attribute('href'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-977a5f0d439d> in <module>
#       3 url1="https://www.walmart.com/search/?query="+search_str
#       4 get1=browser.get(url1)
# ----> 5 review_soup1 = BeautifulSoup(review.content, 'html.parser')
#       6 all_reviews1=review_soup1.find_all('div',class_='wpa-brand-products')#class_='search-result-productimage gridview display-block')
#       7 all_reviews1
#
# AttributeError: 'NoneType' object has no attribute 'content'

# %%
import re
text="de.v,sdfdgfgfgh"
result = re.sub(r'("|.|,)', "", text)
print(result)

# %%
pat = re.compile(r'([A-Z][^\.!?]*[\.!?])', re.M)
pat.findall(walmart_review.txt)
pat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9a9554ce0720> in <module>
#       1 pat = re.compile(r'([A-Z][^\.!?]*[\.!?])', re.M)
# ----> 2 pat.findall(walmart_review.txt)
#       3 pat
#
# NameError: name 'walmart_review' is not defined

# %%
import re
string = 'abc 12\
de 23 \n f45 6'

# matches all whitespace characters
pattern = '\s+'
replace = ''

new_string = re.sub(r'\s+', replace, string, 1) 
print(new_string)
# Out:
# abc12de 23
#  f45 6

# %%
pip install regex
# Out:
# ...
#
# ...
